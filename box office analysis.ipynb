# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\boxoffice intern project\\box_office.csv")
df.head()
# Out:
#    id    budget                           homepage    imdb_id  \
# 0   1  14000000                                NaN  tt2637294
# 1   2  40000000                                NaN  tt0368933
# 2   3   3300000  http://sonyclassics.com/whiplash/  tt2582802
# 3   4   1200000         http://kahaanithefilm.com/  tt1821480
# 4   5         0                                NaN  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# ...

# %%
df.tail()
# Out:
#         id    budget                          homepage    imdb_id  \
# 2995  2996         0                               NaN  tt0109403
# 2996  2997         0                               NaN  tt2364975
# 2997  2998  65000000                               NaN  tt0116908
# 2998  2999  42000000    http://www.alongcamepolly.com/  tt0343135
# 2999  3000  35000000  http://www.abductionthefilm.com/  tt1600195
#
#      original_language           original_title  \
# 2995                en                  Chasers
# 2996                sv              Vi är bäst!
# 2997                en  The Long Kiss Goodnight
# 2998                en         Along Came Polly
# 2999                en                Abduction
#
#                                                overview  popularity  \
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Columns: 203 entries, id to departments_Actors
# dtypes: float64(2), int64(188), object(13)
# memory usage: 4.6+ MB

# %%
df.isnull()
# Out:
#          id  budget  homepage  imdb_id  original_language  original_title  \
# 0     False   False      True    False              False           False
# 1     False   False      True    False              False           False
# 2     False   False     False    False              False           False
# 3     False   False     False    False              False           False
# 4     False   False      True    False              False           False
# ...     ...     ...       ...      ...                ...             ...
# 2995  False   False      True    False              False           False
# 2996  False   False      True    False              False           False
# 2997  False   False      True    False              False           False
# 2998  False   False     False    False              False           False
# 2999  False   False     False    False              False           False
#
#       overview  popularity  poster_path  release_date  ...  departments_Art  \
# ...

# %%
df.isnull().sum()
# Out:
# id                               0
# budget                           0
# homepage                      2054
# imdb_id                          0
# original_language                0
#                               ...
# departments_Directing            0
# departments_Editing              0
# departments_Visual Effects       0
# departments_Lighting             0
# departments_Actors               0
# Length: 203, dtype: int64

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#        has_collection   num_genres  genre_Drama  genre_Comedy  genre_Thriller  \
# count     3000.000000  3000.000000  3000.000000   3000.000000     3000.000000
# mean         0.201333     2.503667     0.510333      0.342667        0.263000
# ...

# %%
df.head()
# Out:
#    id    budget                           homepage    imdb_id  \
# 0   1  14000000                                NaN  tt2637294
# 1   2  40000000                                NaN  tt0368933
# 2   3   3300000  http://sonyclassics.com/whiplash/  tt2582802
# 3   4   1200000         http://kahaanithefilm.com/  tt1821480
# 4   5         0                                NaN  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# ...

# %%
df["original_language"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(df["budget"])
# Out:
# (array([2.411e+03, 3.630e+02, 1.230e+02, 5.500e+01, 2.000e+01, 1.700e+01,
#         7.000e+00, 3.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.00e+00, 3.80e+07, 7.60e+07, 1.14e+08, 1.52e+08, 1.90e+08,
#         2.28e+08, 2.66e+08, 3.04e+08, 3.42e+08, 3.80e+08]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Stat

# %%
df["budget"].mean()
# Out:
# 22531334.11

# %%
df["budget"].median()
# Out:
# 8000000.0

# %%
df["budget"].mode()
# Out:
# 0    0
# Name: budget, dtype: int64

# %%
df["budget"].max()
# Out:
# 380000000

# %%
df["budget"].min()
# Out:
# 0

# %% [markdown]
# # Range

# %%
df["budget"].skew()
# Out:
# 3.1035303484688876

# %%
df["budget"].kurt()
# Out:
# 13.228396629071717

# %% [markdown]
# # Box plot

# %%
plt.boxplot(df['budget'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29a63cd9880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29a63cd9ee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29a63cd95b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29a63cf0400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29a63cf06d0>],
#  'means': []}

# %%
sns.histplot(df['budget'], color= 'red', kde= True);

# %%
df.head()
# Out:
#    id    budget                           homepage    imdb_id  \
# 0   1  14000000                                NaN  tt2637294
# 1   2  40000000                                NaN  tt0368933
# 2   3   3300000  http://sonyclassics.com/whiplash/  tt2582802
# 3   4   1200000         http://kahaanithefilm.com/  tt1821480
# 4   5         0                                NaN  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# ...

# %%
df["popularity"]
# Out:
# 0        6.575393
# 1        8.248895
# 2       64.299990
# 3        3.174936
# 4        1.148070
#           ...
# 2995     9.853270
# 2996     3.727996
# 2997    14.482345
# 2998    15.725542
# 2999    10.512109
# Name: popularity, Length: 3000, dtype: float64

# %%
df["popularity"].hist()
# Out:
# <AxesSubplot:>

# %%
df["popularity"].skew()
# Out:
# 14.377406732929892

# %%
df["popularity"].kurt()
# Out:
# 280.104567554732

# %%
plt.boxplot(df['popularity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29a6452d280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29a6452d820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29a6452d0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29a6452ddc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29a6453a0d0>],
#  'means': []}

# %%
sns.histplot(df['popularity'], color= 'red', kde= True);

# %%
df["departments_Camera"]
# Out:
# 0       8
# 1       1
# 2       4
# 3       0
# 4       0
#        ..
# 2995    1
# 2996    1
# 2997    1
# 2998    9
# 2999    3
# Name: departments_Camera, Length: 3000, dtype: int64

# %%
df["departments_Camera"].hist()
# Out:
# <AxesSubplot:>

# %%
df["departments_Camera"].skew()
# Out:
# 2.5832358331968015

# %%
df["departments_Camera"].kurt()
# Out:
# 7.802414011746686

# %%
a
